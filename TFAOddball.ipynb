# %%
import numpy as np
import pandas as pd
#读取
path=r'F:/desktop/resultend/tfa/oddball/miu/miu.xls'
fre_col=['dataset', 'channel', 'epoch', 'xmax',
               'ymax', 'cmax','xmin', 'ymin', 'cmin','cmean']
f=pd.read_excel(r'{}'.format(path),header=None,names=fre_col)
res = f["dataset"].str.split('sp_filter ica butt sel_chan chanlocs',expand= True)
f[['conditions', 'sub']]=res
cod=f["conditions"].str.split('bl avg cwt amplitude bl reref ar-amp ep_',expand= True)
f[['number','condition']]=cod
f=f[['condition', 'sub', 'channel', 'xmax',
               'ymax', 'cmax','xmin', 'ymin', 'cmin','cmean']]
f=f.astype({'condition':'int'})


value='cmean'
channel="C4"
h=f[f['channel']==channel]
a=h[h['condition']==52]
b=h[h['condition']==53]
c=h[h['condition']==54]
d=h[h['condition']==55]
e=h[h['condition']==56]
g=h[h['condition']==57]
df = pd.DataFrame(list(zip(a[value],b[value],c[value],d[value],e[value],g[value],)),
                  columns=['图片目标','图片非目标','组合目标',
                               '组合非目标','文字目标','文字非目标'],
                index=e['sub'])
df['图片差异波']=df['图片目标']- df['图片非目标']
df['组合差异波']=df['组合目标']-  df['组合非目标']
df['文字差异波']=df['文字目标']- df['文字非目标']
df = df.rename(columns=lambda x: channel+x)
df.to_csv(r'{}{}_{}.csv'.format(path,value,channel), encoding='utf_8_sig')

# %%
 str(f["channel"].unique())

# %%
df
# Out:
#               FZ图片目标   FZ图片非目标    FZ组合目标   FZ组合非目标   FZ文字目标   FZ文字非目标  \
# sub
#  10APPEND   0.280870  0.336270 -0.106630  0.205800  0.29977 -0.038996
#  sub11      0.383130  0.287560  0.412140  0.379210  0.24283  0.286920
#  sub12      0.165930  0.011643  0.546930  0.079623  0.14922  0.183040
#  sub13      0.377150  0.234600  0.474360  0.389420  0.33824  0.242170
#  sub14      0.459080  0.126920  0.123450  0.159750  0.35080  0.278520
#  sub16      0.058578  0.037753  0.179090 -0.134720  0.20908  0.055125
#  sub17      0.363560  0.240300  0.409020  0.207320  0.28126  0.248220
#  sub18      0.374500  0.232550  0.114880  0.382570  0.34550  0.443460
#  sub19      0.422630  0.138210  0.529390  0.356540  0.11953  0.198710
#  sub2       0.625080 -0.041846  0.240280  0.193420  0.26448  0.243560
#  sub20      0.909710  0.149810  1.067300  0.183920  0.60476  0.374490
#  sub21      0.463190  0.249990  0.460080  0.276830  0.48901  0.287930
#  sub22      0.607250  0.052048  0.311360  0.062073  0.38804  0.021045
#  sub23-new  0.268930  0.094751  0.395270  0.418810  0.43074  0.283580
#  sub23      0.552600  0.299160 -0.031412  0.275800  0.22440  0.060477
#  sub24-new  0.198060  0.200950  0.335810  0.364970  0.23912  0.141440
#  sub25-new  0.551750  0.119350  0.301710  0.158880  0.17491  0.240590
#  sub3       0.513790  0.100940  0.874440  0.210670  0.43436  0.220030
#  sub4       0.228010  0.155820  0.258080  0.364880  0.64788  0.352330
#  sub5       1.041700  0.274220  0.848260  0.385530  0.68058  0.421700
#  sub6       0.989640  0.256520  0.810660  0.367400  0.66089  0.338840
#  sub7       0.475390  0.129050  0.313100  0.341510  0.21217  0.212910
#  sub8       0.556580  0.354540  0.743110  0.243510  0.28876  0.145200
#  sub9       0.425740  0.580720  0.489560  0.607980  0.54654  0.363310
#
#              FZ图片差异波   FZ组合差异波   FZ文字差异波
# sub
#  10APPEND  -0.055400 -0.312430  0.338766
#  sub11      0.095570  0.032930 -0.044090
#  sub12      0.154287  0.467307 -0.033820
#  sub13      0.142550  0.084940  0.096070
#  sub14      0.332160 -0.036300  0.072280
#  sub16      0.020825  0.313810  0.153955
#  sub17      0.123260  0.201700  0.033040
#  sub18      0.141950 -0.267690 -0.097960
#  sub19      0.284420  0.172850 -0.079180
#  sub2       0.666926  0.046860  0.020920
#  sub20      0.759900  0.883380  0.230270
#  sub21      0.213200  0.183250  0.201080
#  sub22      0.555202  0.249287  0.366995
#  sub23-new  0.174179 -0.023540  0.147160
#  sub23      0.253440 -0.307212  0.163923
#  sub24-new -0.002890 -0.029160  0.097680
#  sub25-new  0.432400  0.142830 -0.065680
#  sub3       0.412850  0.663770  0.214330
#  sub4       0.072190 -0.106800  0.295550
#  sub5       0.767480  0.462730  0.258880
#  sub6       0.733120  0.443260  0.322050
#  sub7       0.346340 -0.028410 -0.000740
#  sub8       0.202040  0.499600  0.143560
#  sub9      -0.154980 -0.118420  0.183230
